# %%
value1 = 234567970
value2 = 2348890

# %% [markdown]
# Here I put : then went to the next space to represent a condition
#
# - This is an If/Then

# %%
if (value1 > 0) & (value2 > 2468): 
    print("Yes, both of these values are greter than their target")

elif (value1 < 234670908):
    print("Our intermediate condition is met")

else: 
    print("No, this value is too low")
# Out:
# Yes, both of these values are greter than their target

# %% [markdown]
# Infinite loop

# %%
while value1 < 0: 
    print(value1, "is less than zero. Running again")
    print(value1, "is the new value!")

# %%
import os
import pyodbc
import pandas as pd

# define creds here (temporary, for class)
os.environ["mssql_ccny_user"] = "julianagimolieca57"
os.environ["mssql_ccny_pw"] = "CCny24171157"

print("env set ")
# Out:
# env set

# %%
server = "johndroescher.com"
default_db = "Sum_2025"
username = os.environ["mssql_ccny_user"]
password = os.environ["mssql_ccny_pw"]

cnxn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    f"SERVER={server};"
    f"DATABASE={default_db};"
    f"UID={username};"
    f"PWD={password}"
)

cnxn.autocommit = True
conn = cnxn.cursor()
print("connected ")
# Out:
# connected

# %%
import pandas as pd 
import pyodbc
import os

server = 'johndroescher.com'
default_db = 'Sum_2025'
username = os.environ["mssql_ccny_user"]
password = os.environ["mssql_ccny_pw"]

cnxn = pyodbc.connect(
        "DRIVER={ODBC Driver 17 for SQL Server};SERVER="
        + server 
        + ";DATABASE="
        + default_db
        + ";UID="
        + username
        + ";PWD="
        + password 
    )

    # Set autocommit for queries to connect to SQL 
cnxn.autocommit = True

# Return the cursor
conn = cnxn.cursor()

# %%
sql_query = "SELECT * FROM tx_deathrow WHERE first_name LIKE 'John%'"

tx_death = pd.read_sql(sql_query, cnxn)
# Out:
# /var/folders/8g/9gvwpcx5643bbxxh_35f037w0000gq/T/ipykernel_38943/721023025.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tx_death = pd.read_sql(sql_query, cnxn)

# %%
tx_death_johns = tx_death[tx_death['First_Name'].str.contains("John")]

# %%
tx_death[tx_death['First_Name'].str.contains("Char")]['Age_at_Execution'].mean()
# Out:
# nan

# %%
tx_death.shape
# Out:
# (24, 18)

# %%
tx_death_john.shape
# Out:
# (24, 18)

# %%
# %pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sp500['Close']
#
# NameError: name 'sp500' is not defined
