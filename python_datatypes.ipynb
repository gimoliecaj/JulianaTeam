# %% [markdown]
# ## Python Data Types
# We will use this Jupyter Notebook to discuss basic Python Datatypes

# %% [markdown]
# Folder for practice based on class lectures

# %%
bool(8)
# Out:
# True

# %%
bool (0 > 8)
# Out:
# False

# %% [markdown]
# Conditionals
# 1. >
# 2. <
# 3. >=
# 4. <=
# 5. ==
# 6. |=
# 7. or ... |
# 8. and ... &

# %%
bool(0 & 8)
# Out:
# False

# %% [markdown]
# False because '&' is determined as both cnditions must be true. 'Or' means that at least one condittion needs to be true.

# %%
bool(0 | 8)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(8)
# Out:
# True

# %%
bool(1 & 8)
# Out:
# False

# %%
bool (1) & bool(8)
# Out:
# True

# %%
num1 = 8
num2 = 8
num3 = 7

num_input = int(input("Input a number"))
bool (num1 & num_input)
# Out:
# True

# %%
bool (num1 & num2)
# Out:
# True

# %%
bool (num2 & num3)
# Out:
# False

# %%
bool (num1 & num_input)
# Out:
# True

# %% [markdown]
# mutability: a value that can be changed and iterability: an object that contains other elements.

# %%
type(8)
# Out:
# int

# %% [markdown]
# this is a float because it contains a decimal

# %%
type(8.0)
# Out:
# float

# %%
my_string1 = "can't" 
my_string2 = 'John said "we shokd make sure we know the definitions of mutuability and interability"'

my_string3 = "The current rate of inflation for the US economy was 2.5% "

type(my_string3)
# Out:
# str

# %%
my_string1 + my_string3
# Out:
# "can'tThe current rate of inflation for the US economy was 2.5% "

# %%
my_string1 *2
# Out:
# "can'tcan't"

# %%
my_string1 * my_string3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 my_string1 * my_string3
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# this doen here gives us an error because we can't multi

# %% [markdown]
# A list is denoted with brackets

# %%
my_list = ['this is the first element', 2424, my_string3]

# %%
my_list
# Out:
# ['this is the first element',
#  2424,
#  'The current rate of inflation for the US economy was 2.5% ']

# %%
my_list[0]
# Out:
# 'this is the first element'

# %%
my_list[1]
# Out:
# 2424

# %%
type[my_list[2]]
# Out:
# type['The current rate of inflation for the US economy was 2.5% ']

# %%
['this is the first element', 2424, my_string2, my_string3, my_list][4][0]
# Out:
# 'this is the first element'

# %%
my_list2 = [2424, my_string2, my_string3, my_list]

# %%
my_list2.append(['some other list'])

# %%
my_list2
# Out:
# [2424,
#  'John said "we shokd make sure we know the definitions of mutuability and interability"',
#  'The current rate of inflation for the US economy was 2.5% ',
#  ['this is the first element',
#   2424,
#   'The current rate of inflation for the US economy was 2.5% '],
#  ['some other list']]

# %%
my_tuple = ('some element', 2424, 987.2009, my_list2, my_string3)

# %% [markdown]
# you cant change th evalue of a tuple.
# We use append to change a value of something

# %%
my_tuple.append(['a new element'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 my_tuple.append(['a new element'])
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
my_tuple[0]
# Out:
# 'some element'

# %%
my_tuple[1:3]
# Out:
# (2424, 987.2009)

# %% [markdown]
# This is a set

# %%
my_list3 = [3, 2, 65, 2, 3 ,456, 73, 2345, 89, 3, 4, 2,]

# %%
set(my_list3)
# Out:
# {2, 3, 4, 65, 73, 89, 456, 2345}

# %%
set(my_string3)
# Out:
# {' ',
#  '%',
#  '.',
#  '2',
#  '5',
#  'S',
#  'T',
#  'U',
#  'a',
#  'c',
#  'e',
#  'f',
#  'h',
#  'i',
#  'l',
#  'm',
#  'n',
#  'o',
#  'r',
#  's',
#  't',
#  'u',
#  'w',
#  'y'}

# %% [markdown]
# we cant do a set on a list
# Because it cant compare or identify if the characters on list are unique or not

# %% [markdown]
# The dictionary
# - another tyoe of data

# %%
my_list
# Out:
# ['this is the first element',
#  2424,
#  'The current rate of inflation for the US economy was 2.5% ']

# %%
my_dict = {"my_list": my_list}
